# %%
import pandas as pd
import numpy as np
from ast import literal_eval

# %%
df = pd.read_csv("./data/recipedata-grouped.csv", index_col=0)

# %% [markdown]
# We are going to drop columns we are not interested in, and columns with too many missing values.

# %%
df = df.drop(['gaps',
              'lowFodmap', 
              'aggregateLikes', 
              'spoonacularScore',
              'weightWatcherSmartPoints',
              'creditsText', 
              'sourceName',
              'sourceUrl', 
              'image', 
              'imageType',
              'occasions',
              'author', 
              'nutrition', 
              'winePairing',
              'originalId', 
              'spoonacularSourceUrl', 
              'license', 
              'preparationMinutes', 
              'cookingMinutes', 
              'cuisines',
              # 'diets', 
              'dishTypes', 'analyzedInstructions'], axis=1)
# df.head()

# %%
# drop 
df = df.replace('[]', np.nan)
for column in df.columns:
    col = df[column]
    n_empty = sum(col.isna()==True)
    print(column, n_empty)
# Out:
# vegetarian 0
# vegan 0
# glutenFree 0
# dairyFree 0
# veryHealthy 0
# cheap 0
# veryPopular 0
# sustainable 0
# healthScore 0
# pricePerServing 0
# extendedIngredients 0
# id 0
# title 0
# readyInMinutes 0
# servings 0
# summary 2
# diets 289
# instructions 83

# %% [markdown]
# We are not going to drop the summary and instructions columns because they are important for our NLP model. Instead, we are going to drop the data points (rows).

# %%
print("Before dropping rows: ", df.shape)
df = df.dropna()
print("After dropping rows:", df.shape)
# Out:
# Before dropping rows:  (1422, 18)
# After dropping rows: (1060, 18)

# %%
df.head()
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0       False  False        True      False        False  False        False
# 1        True   True        True       True         True  False        False
# 2        True   True        True       True        False  False        False
# 3        True  False        True       True        False  False        False
# 4        True  False       False      False        False  False        False
#
#    sustainable  healthScore  pricePerServing  \
# 0        False         24.0           274.60
# 1        False        100.0           126.27
# 2        False         40.0            43.68
# 3        False          4.0            86.32
# 4        False          3.0            59.75
#
#                                  extendedIngredients      id  \
# 0  [{'id': 1032028, 'aisle': 'Ethnic Foods;Spices...  780001
# 1  [{'id': 4053, 'aisle': 'Oil, Vinegar, Salad Dr...  663559
# 2  [{'id': 1032035, 'aisle': 'Spices and Seasonin...  716195
# 3  [{'id': 1123, 'aisle': 'Milk, Eggs, Other Dair...  662276
# 4  [{'id': 1001, 'aisle': 'Milk, Eggs, Other Dair...  633970
#
#                                   title  readyInMinutes  servings  \
# 0                 Pesto Chicken Zoodles              45         3
# 1                Tomato and lentil soup              45         4
# 2             Spicy Indian-Style Hummus              45        12
# 3  Sun Dried Tomato and Herb Baked Eggs              25         1
# 4                  Banana & Oreo Muffin              45         4
#
#                                              summary  \
# 0  Need a <b>gluten free and primal main course</...
# 1  Tomato and lentil soup takes about <b>about 45...
# 2  Spicy Indian-Style Hummus might be just the ho...
# 3  Sun Dried Tomato and Herb Baked Eggs might be ...
# 4  Banana & Oreo Muffin is a <b>lacto ovo vegetar...
#
#                                         instructions
# 0  To get started, place 1/4 cup of olive oil int...
# 1  Saut onion and garlic in olive oil for 5 minut...
# 2  <p>Rinse the chickpeas and soak for 8 hours or...
# 3  <ol><li>Preheat oven to 350 F.</li><li>Cover t...
# 4  Sift the flour, baking power and baking soda t...

# %%
# Count the number of empty cells in each column
df.to_csv(f"data/cleaneddata.csv")

# %%
pd.DataFrame(map(literal_eval, df["extendedIngredients"]))
# Out:
#                                                      0   \
# 0     {'id': 1032028, 'aisle': 'Ethnic Foods;Spices ...
# 1     {'id': 4053, 'aisle': 'Oil, Vinegar, Salad Dre...
# 2     {'id': 1032035, 'aisle': 'Spices and Seasoning...
# 3     {'id': 1123, 'aisle': 'Milk, Eggs, Other Dairy...
# 4     {'id': 1001, 'aisle': 'Milk, Eggs, Other Dairy...
# ...                                                 ...
# 1132  {'id': 2064, 'aisle': 'Produce', 'image': 'min...
# 1133  {'id': 6008, 'aisle': 'Canned and Jarred', 'im...
# 1134  {'id': 1001, 'aisle': 'Milk, Eggs, Other Dairy...
# 1135  {'id': 2048, 'aisle': 'Oil, Vinegar, Salad Dre...
# 1136  {'id': 18371, 'aisle': 'Baking', 'image': 'whi...
#
#                                                      1   \
# 0     {'id': 5062, 'aisle': 'Meat', 'image': 'chicke...
# 1     {'id': 11282, 'aisle': 'Produce', 'image': 'br...
# 2     {'id': 2031, 'aisle': 'Spices and Seasonings',...
# 3     {'id': 2044, 'aisle': 'Produce;Spices and Seas...
# 4     {'id': 19335, 'aisle': 'Baking', 'image': 'sug...
# ...                                                 ...
# 1132  {'id': 18617, 'aisle': 'Sweet Snacks', 'image'...
# 1133  {'id': 23584, 'aisle': 'Meat', 'image': 'top-s...
# 1134  {'id': 1017, 'aisle': 'Cheese', 'image': 'crea...
# 1135  {'id': 9037, 'aisle': 'Produce', 'image': 'avo...
# 1136  {'id': 10020129, 'aisle': 'Baking', 'image': '...
#
#                                                      2   \
# 0     {'id': 2044, 'aisle': 'Produce;Spices and Seas...
# 1     {'id': 11215, 'aisle': 'Produce', 'image': 'ga...
# 2     {'id': 16056, 'aisle': 'Pasta and Rice;Canned ...
# 3     {'id': 11297, 'aisle': 'Produce;Spices and Sea...
# 4     {'id': 20081, 'aisle': 'Baking', 'image': 'flo...
# ...                                                 ...
# 1132  {'id': 2021, 'aisle': 'Spices and Seasonings',...
# 1133  {'id': 10011090, 'aisle': 'Produce', 'image': ...
# 1134  {'id': 1125, 'aisle': 'Milk, Eggs, Other Dairy...
# 1135  {'id': 11080, 'aisle': 'Produce', 'image': 'be...
# 1136  {'id': 19336, 'aisle': 'Baking', 'image': 'pow...
#
#                                                      3   \
# 0     {'id': 11215, 'aisle': 'Produce', 'image': 'ga...
# 1     {'id': 11124, 'aisle': 'Produce', 'image': 'sl...
# 2     {'id': 11156, 'aisle': 'Produce', 'image': 'fr...
# 3     {'id': 4053, 'aisle': 'Oil, Vinegar, Salad Dre...
# 4     {'id': 18371, 'aisle': 'Baking', 'image': 'whi...
# ...                                                 ...
# 1132  {'id': 1065062, 'aisle': None, 'image': 'whole...
# 1133  {'id': 19334, 'aisle': 'Baking', 'image': 'lig...
# 1134  {'id': 1125, 'aisle': 'Milk, Eggs, Other Dairy...
# 1135  {'id': 11291, 'aisle': 'Produce', 'image': 'sp...
# 1136  {'id': 18373, 'aisle': 'Spices and Seasonings;...
#
#                                                      4   \
# 0     {'id': 1062047, 'aisle': 'Spices and Seasoning...
# 1     {'id': 10011693, 'aisle': 'Canned and Jarred',...
# 2     {'id': 11216, 'aisle': 'Produce;Ethnic Foods;S...
# 3     {'id': 11955, 'aisle': 'Canned and Jarred;Prod...
# 4     {'id': 18372, 'aisle': 'Baking', 'image': 'whi...
# ...                                                 ...
# 1132  {'id': 1197, 'aisle': 'Milk, Eggs, Other Dairy...
# 1133  {'id': 11124, 'aisle': 'Produce', 'image': 'sl...
# 1134  {'id': 1123, 'aisle': 'Milk, Eggs, Other Dairy...
# 1135  {'id': 11446, 'aisle': 'Ethnic Foods', 'image'...
# 1136  {'id': 1123, 'aisle': 'Milk, Eggs, Other Dairy...
#
#                                                      5   \
# 0     {'id': 4053, 'aisle': 'Oil, Vinegar, Salad Dre...
# 1     {'id': 2004, 'aisle': 'Produce;Spices and Seas...
# 2     {'id': 11297, 'aisle': 'Produce;Spices and Sea...
# 3                                                  None
# 4     {'id': 1123, 'aisle': 'Milk, Eggs, Other Dairy...
# ...                                                 ...
# 1132                                               None
# 1133  {'id': 10011135, 'aisle': 'Produce', 'image': ...
# 1134  {'id': 20081, 'aisle': 'Baking', 'image': 'flo...
# 1135  {'id': 4053, 'aisle': 'Oil, Vinegar, Salad Dre...
# 1136  {'id': 12311111, 'aisle': 'Baking', 'image': '...
#
#                                                      6   \
# 0     {'id': 1033, 'aisle': 'Cheese', 'image': 'parm...
# 1     {'id': 14412, 'aisle': 'Beverages', 'image': '...
# 2     {'id': 11215, 'aisle': 'Produce', 'image': 'ga...
# 3                                                  None
# 4     {'id': 1095, 'aisle': 'Baking', 'image': 'evap...
# ...                                                 ...
# 1132                                               None
# 1133  {'id': 11420421, 'aisle': 'Pasta and Rice', 'i...
# 1134  {'id': 9156, 'aisle': 'Produce', 'image': 'zes...
# 1135  {'id': 11429, 'aisle': 'Produce', 'image': 'ra...
# 1136  {'id': 10319297, 'aisle': 'Nut butters, Jams, ...
#
#                                                      7   \
# 0     {'id': 1102047, 'aisle': 'Spices and Seasoning...
# 1     {'id': 16069, 'aisle': 'Pasta and Rice;Canned ...
# 2     {'id': 1002013, 'aisle': 'Spices and Seasoning...
# 3                                                  None
# 4     {'id': 9040, 'aisle': 'Produce', 'image': 'ban...
# ...                                                 ...
# 1132                                               None
# 1133  {'id': 20027, 'aisle': 'Baking', 'image': 'whi...
# 1134  {'id': 9216, 'aisle': 'Produce', 'image': 'ora...
# 1135  {'id': 12516, 'aisle': 'Savory Snacks', 'image...
# 1136  {'id': 2047, 'aisle': 'Spices and Seasonings',...
#
#                                                      8   \
# 0     {'id': 11477, 'aisle': 'Produce', 'image': 'zu...
# 1     {'id': 2047, 'aisle': 'Spices and Seasonings',...
# 2     {'id': 1002014, 'aisle': 'Spices and Seasoning...
# 3                                                  None
# 4     {'id': 10018166, 'aisle': 'Sweet Snacks', 'ima...
# ...                                                 ...
# 1132                                               None
# 1133  {'id': 11260, 'aisle': 'Produce', 'image': 'mu...
# 1134  {'id': 9302, 'aisle': 'Produce', 'image': 'ras...
# 1135  {'id': 4528, 'aisle': 'Oil, Vinegar, Salad Dre...
# 1136  {'id': 19335, 'aisle': 'Baking', 'image': 'sug...
#
#                                                      9   ...    18    19  \
# 0                                                  None  ...  None  None
# 1     {'id': 11297, 'aisle': 'Produce;Spices and Sea...  ...  None  None
# 2     {'id': 1002030, 'aisle': 'Spices and Seasoning...  ...  None  None
# 3                                                  None  ...  None  None
# 4     {'id': 1012050, 'aisle': 'Baking', 'image': 'v...  ...  None  None
# ...                                                 ...  ...   ...   ...
# 1132                                               None  ...  None  None
# 1133  {'id': 1022020, 'aisle': 'Spices and Seasoning...  ...  None  None
# 1134  {'id': 2047, 'aisle': 'Spices and Seasonings',...  ...  None  None
# 1135                                               None  ...  None  None
# 1136  {'id': 2050, 'aisle': 'Baking', 'image': 'vani...  ...  None  None
#
#         20    21    22    23    24    25    26    27
# 0     None  None  None  None  None  None  None  None
# 1     None  None  None  None  None  None  None  None
# 2     None  None  None  None  None  None  None  None
# 3     None  None  None  None  None  None  None  None
# 4     None  None  None  None  None  None  None  None
# ...    ...   ...   ...   ...   ...   ...   ...   ...
# 1132  None  None  None  None  None  None  None  None
# 1133  None  None  None  None  None  None  None  None
# 1134  None  None  None  None  None  None  None  None
# 1135  None  None  None  None  None  None  None  None
# 1136  None  None  None  None  None  None  None  None
#
# [1137 rows x 28 columns]

# %%
literal_eval(df["extendedIngredients"].iloc[0])
# Out:
# [{'id': 1032028,
#   'aisle': 'Ethnic Foods;Spices and Seasonings',
#   'image': 'chili-powder.jpg',
#   'consistency': 'solid',
#   'name': 'cajun seasoning',
#   'nameClean': 'cajun seasoning',
#   'original': '1 tsp Cajun seasoning',
#   'originalName': 'Cajun seasoning',
#   'amount': 1.0,
#   'unit': 'tsp',
#   'meta': [],
#   'measures': {'us': {'amount': 1.0,
#     'unitShort': 'tsp',
#     'unitLong': 'teaspoon'},
#    'metric': {'amount': 1.0, 'unitShort': 'tsp', 'unitLong': 'teaspoon'}}},
#  {'id': 5062,
#   'aisle': 'Meat',
#   'image': 'chicken-breasts.png',
#   'consistency': 'solid',
#   'name': 'chicken breasts',
#   'nameClean': 'chicken breast',
#   'original': '2 8oz chicken breasts seasoned, grilled, and sliced (batch cook chicken for the week to save time!)',
#   'originalName': 'chicken breasts seasoned, grilled, and sliced (batch cook chicken for the week to save time!)',
#   'amount': 16.0,
#   'unit': 'oz',
#   'meta': ['sliced', 'for the week to save time!)'],
#   'measures': {'us': {'amount': 16.0, 'unitShort': 'oz', 'unitLong': 'ounces'},
#    'metric': {'amount': 453.592, 'unitShort': 'g', 'unitLong': 'grams'}}},
#  {'id': 2044,
#   'aisle': 'Produce;Spices and Seasonings',
#   'image': 'basil.jpg',
#   'consistency': 'solid',
#   'name': 'fresh basil leaves',
#   'nameClean': 'fresh basil',
#   'original': '3/4 cup fresh basil leaves',
#   'originalName': 'fresh basil leaves',
#   'amount': 0.75,
#   'unit': 'cup',
#   'meta': ['fresh'],
#   'measures': {'us': {'amount': 0.75, 'unitShort': 'cups', 'unitLong': 'cups'},
#    'metric': {'amount': 177.441,
#     'unitShort': 'ml',
#     'unitLong': 'milliliters'}}},
#  {'id': 11215,
#   'aisle': 'Produce',
#   'image': 'garlic.png',
#   'consistency': 'solid',
#   'name': 'garlic',
#   'nameClean': 'garlic',
#   'original': '1 clove garlic, peeled',
#   'originalName': 'garlic, peeled',
#   'amount': 1.0,
#   'unit': 'clove',
#   'meta': ['peeled'],
#   'measures': {'us': {'amount': 1.0,
#     'unitShort': 'clove',
#     'unitLong': 'clove'},
#    'metric': {'amount': 1.0, 'unitShort': 'clove', 'unitLong': 'clove'}}},
#  {'id': 1062047,
#   'aisle': 'Spices and Seasonings',
#   'image': 'garlic-salt.jpg',
#   'consistency': 'solid',
#   'name': 'garlic salt',
#   'nameClean': 'garlic salt',
#   'original': '1 Tbsp garlic salt',
#   'originalName': 'garlic salt',
#   'amount': 1.0,
#   'unit': 'Tbsp',
#   'meta': [],
#   'measures': {'us': {'amount': 1.0, 'unitShort': 'Tbsp', 'unitLong': 'Tbsp'},
#    'metric': {'amount': 1.0, 'unitShort': 'Tbsp', 'unitLong': 'Tbsp'}}},
#  {'id': 4053,
#   'aisle': 'Oil, Vinegar, Salad Dressing',
#   'image': 'olive-oil.jpg',
#   'consistency': 'liquid',
#   'name': 'olive oil',
#   'nameClean': 'olive oil',
#   'original': '1/2 cup olive oil (separated into 2 – 1/4 cups)',
#   'originalName': 'olive oil (separated into 2 – 1/4 cups)',
#   'amount': 0.5,
#   'unit': 'cup',
#   'meta': ['separated', '( into 2 -)'],
#   'measures': {'us': {'amount': 0.5, 'unitShort': 'cups', 'unitLong': 'cups'},
#    'metric': {'amount': 118.294,
#     'unitShort': 'ml',
#     'unitLong': 'milliliters'}}},
#  {'id': 1033,
#   'aisle': 'Cheese',
#   'image': 'parmesan.jpg',
#   'consistency': 'solid',
#   'name': 'parmesan cheese',
#   'nameClean': 'parmesan',
#   'original': '1 Tbsp grated parmesan cheese',
#   'originalName': 'grated parmesan cheese',
#   'amount': 1.0,
#   'unit': 'Tbsp',
#   'meta': ['grated'],
#   'measures': {'us': {'amount': 1.0, 'unitShort': 'Tbsp', 'unitLong': 'Tbsp'},
#    'metric': {'amount': 1.0, 'unitShort': 'Tbsp', 'unitLong': 'Tbsp'}}},
#  {'id': 1102047,
#   'aisle': 'Spices and Seasonings',
#   'image': 'salt-and-pepper.jpg',
#   'consistency': 'solid',
#   'name': 'salt and pepper',
#   'nameClean': 'salt and pepper',
#   'original': 'salt and pepper to taste',
#   'originalName': 'salt and pepper to taste',
#   'amount': 3.0,
#   'unit': 'servings',
#   'meta': ['to taste'],
#   'measures': {'us': {'amount': 3.0,
#     'unitShort': 'servings',
#     'unitLong': 'servings'},
#    'metric': {'amount': 3.0,
#     'unitShort': 'servings',
#     'unitLong': 'servings'}}},
#  {'id': 11477,
#   'aisle': 'Produce',
#   'image': 'zucchini.jpg',
#   'consistency': 'solid',
#   'name': 'zucchini',
#   'nameClean': 'zucchini',
#   'original': '2 large zucchini, spiraled',
#   'originalName': 'zucchini, spiraled',
#   'amount': 2.0,
#   'unit': 'large',
#   'meta': [],
#   'measures': {'us': {'amount': 2.0,
#     'unitShort': 'large',
#     'unitLong': 'larges'},
#    'metric': {'amount': 2.0, 'unitShort': 'large', 'unitLong': 'larges'}}}]
