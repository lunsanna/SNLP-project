# %%
import pandas as pd
import numpy as np
from ast import literal_eval
import re

# %%
df = pd.read_csv("./data/recipedata-grouped.csv", index_col=0)

# %% [markdown]
# ## Remove columns that we are not going to use

# %% [markdown]
# We are going to drop columns we are not interested in, and columns with too many missing values.

# %%
df = df.drop(['id', 
              'gaps',
              'lowFodmap', 
              'aggregateLikes', 
              'spoonacularScore',
              'weightWatcherSmartPoints',
              'creditsText', 
              'sourceName',
              'sourceUrl', 
              'image', 
              'imageType',
              'occasions',
              'author', 
              'nutrition', 
              'winePairing',
              'originalId', 
              'spoonacularSourceUrl', 
              'license', 
              'preparationMinutes', 
              'cookingMinutes', 
              'cuisines',
              # 'diets', 
              'dishTypes', 'analyzedInstructions'], axis=1)
# df.head()

# %% [markdown]
# ## Drop data points with missing data (if needed)

# %%
# check how many missing values we have for each column
df = df.replace('[]', np.nan)
for column in df.columns:
    col = df[column]
    n_empty = sum(col.isna()==True)
    print(column, n_empty)
# Out:
# vegetarian 0
# vegan 0
# glutenFree 0
# dairyFree 0
# veryHealthy 0
# cheap 0
# veryPopular 0
# sustainable 0
# healthScore 0
# pricePerServing 0
# extendedIngredients 0
# title 0
# readyInMinutes 0
# servings 0
# summary 4
# diets 818
# instructions 196

# %% [markdown]
# We only have missing values in the "summary", "diets" and "instructions" columns. I am going to keep all the data points, but you can drop some of them if you want.

# %%
print("Before dropping rows: ", df.shape)
# df = df.dropna()
print("After dropping rows:", df.shape)
# Out:
# Before dropping rows:  (3859, 17)
# After dropping rows: (3859, 17)

# %%
df.head()
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True  False        True      False        False  False        False
# 1       False  False       False      False        False  False        False
# 2       False  False       False      False        False  False        False
# 3        True  False        True      False        False  False        False
# 4       False  False        True      False        False  False        False
#
#    sustainable  healthScore  pricePerServing  \
# 0        False         26.0           510.34
# 1        False         13.0           204.73
# 2        False         20.0           145.24
# 3        False         22.0           106.64
# 4        False         35.0           554.27
#
#                                  extendedIngredients  \
# 0  [{'id': 1034053, 'aisle': 'Oil, Vinegar, Salad...
# 1  [{'id': 10211821, 'aisle': 'Produce', 'image':...
# 2  [{'id': 10120420, 'aisle': 'Pasta and Rice', '...
# 3  [{'id': 9037, 'aisle': 'Produce', 'image': 'av...
# 4  [{'id': 11011, 'aisle': 'Produce', 'image': 'a...
#
#                                                title  readyInMinutes  \
# 0                    Roasted Butternut Squash Bisque              45
# 1                     Turkey Goulash By Mommie Cooks              45
# 2  What to make for dinner tonight?? Bruschetta S...              35
# 3                    Not Your Normal Seven Layer Dip              15
# 4  Pan-seared salmon with brown butter lime sauce...              45
#
#    servings                                            summary  \
# 0         6  Roasted Butternut Squash Bisque could be just ...
# 1         6  Turkey Goulash By Mommie Cooks might be just t...
# 2         5  You can never have too many main course recipe...
# 3        12  Not Your Normal Seven Layer Dip might be just ...
# 4         4  Pan-seared salmon with brown butter lime sauce...
#
#                                                diets  \
# 0  ['gluten free', 'lacto ovo vegetarian', 'primal']
# 1                                                NaN
# 2                                                NaN
# 3            ['gluten free', 'lacto ovo vegetarian']
# 4           ['gluten free', 'primal', 'pescatarian']
#
#                                         instructions
# 0  For garlic broth:\nAdd all ingredients to the ...
# 1  <ol><li>If you're using ground turkey, start o...
# 2  wash and rinse pork chops and place into the s...
# 3  Layer your bowl with refried beans.Add a layer...
# 4  <ol><li>In a frying pan, melt the butter over ...

# %% [markdown]
# ## Convert the `extendedIngredients` column to a simple list of ingredient names

# %%
evaluated_ingredient = pd.DataFrame(map(literal_eval, df["extendedIngredients"]))

# %%
row, col = evaluated_ingredient.shape
ingredient_names = []

for r in range(row):
    tmp = []
    for c in range(col):
        cell = evaluated_ingredient.iloc[r,c]
        if cell: 
            tmp.append(cell["name"])
    tmp = "; ".join(tmp)
    ingredient_names.append(tmp)

# %%
df["Ingredients"] = pd.Series(ingredient_names)

# %% [markdown]
# If you want to keep the `extendIngredients` column, do not run the following cell.

# %%
df = df.drop(["extendedIngredients"], axis=1)

# %%
# rearrange the columns
columns = df.columns.tolist()
columns = ['title','summary','instructions','Ingredients',
             'vegetarian',
             'vegan',
             'glutenFree',
             'dairyFree',
             'veryHealthy',
             'cheap',
             'veryPopular',
             'sustainable',
             'healthScore',
             'pricePerServing',
             'readyInMinutes',
             'servings',
             'diets',]

# %%
df = df[columns]

# %%
df.head()
# Out:
#                                                title  \
# 0                    Roasted Butternut Squash Bisque
# 1                     Turkey Goulash By Mommie Cooks
# 2  What to make for dinner tonight?? Bruschetta S...
# 3                    Not Your Normal Seven Layer Dip
# 4  Pan-seared salmon with brown butter lime sauce...
#
#                                              summary  \
# 0  Roasted Butternut Squash Bisque could be just ...
# 1  Turkey Goulash By Mommie Cooks might be just t...
# 2  You can never have too many main course recipe...
# 3  Not Your Normal Seven Layer Dip might be just ...
# 4  Pan-seared salmon with brown butter lime sauce...
#
#                                         instructions  \
# 0  For garlic broth:\nAdd all ingredients to the ...
# 1  <ol><li>If you're using ground turkey, start o...
# 2  wash and rinse pork chops and place into the s...
# 3  Layer your bowl with refried beans.Add a layer...
# 4  <ol><li>In a frying pan, melt the butter over ...
#
#                                          Ingredients  vegetarian  vegan  \
# 0  extra virgin olive oil; butter; sweet onions; ...        True  False
# 1  bell pepper; canned diced tomatoes; cooked egg...       False  False
# 2  bow tie pasta; parmigiano reggiano; pasta; por...       False  False
# 3  avocado; canned tomatoes; cilantro; green chil...        True  False
# 4  asparagus spears; butter; butter; garlic; lime...       False  False
#
#    glutenFree  dairyFree  veryHealthy  cheap  veryPopular  sustainable  \
# 0        True      False        False  False        False        False
# 1       False      False        False  False        False        False
# 2       False      False        False  False        False        False
# 3        True      False        False  False        False        False
# 4        True      False        False  False        False        False
#
#    healthScore  pricePerServing  readyInMinutes  servings  \
# 0         26.0           510.34              45         6
# 1         13.0           204.73              45         6
# 2         20.0           145.24              35         5
# 3         22.0           106.64              15        12
# 4         35.0           554.27              45         4
#
#                                                diets
# 0  ['gluten free', 'lacto ovo vegetarian', 'primal']
# 1                                                NaN
# 2                                                NaN
# 3            ['gluten free', 'lacto ovo vegetarian']
# 4           ['gluten free', 'primal', 'pescatarian']

# %% [markdown]
# ## Remove the html tags, urls and line breaks from the text data

# %% [markdown]
# We will use the following four columns as text data:
# 1. title
# 2. summary
# 3. instructions
# 4. ingredients

# %%
for r in range(row):
    for c in range(4): # only the 4 first columns are text data that we are going to use
        text = df.iloc[r, c]
        if text is not np.nan and text is not None:
            # remove line breaks and html tags
            text = re.sub(r"<[^>]*>'|[\n\r]+", " ", text).lower()
            # remove urls 
            text = re.sub(r"https?:\/\/(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)", " ", text)
            # remove extra spaces
            text = re.sub(r"\s\s+", " ", text)
            df.iloc[r, c] = text

# %%
df
# Out:
#                                                 title  \
# 0                     roasted butternut squash bisque
# 1                      turkey goulash by mommie cooks
# 2   what to make for dinner tonight?? bruschetta s...
# 3                     not your normal seven layer dip
# 4   pan-seared salmon with brown butter lime sauce...
# ..                                                ...
# 28                         scalloped potato casserole
# 29                                no-bake cereal bars
# 30                                  nutty fudge torte
# 31                      lemony carrot salad with dill
# 32                                  pineapple squares
#
#                                               summary  \
# 0   roasted butternut squash bisque could be just ...
# 1   turkey goulash by mommie cooks might be just t...
# 2   you can never have too many main course recipe...
# 3   not your normal seven layer dip might be just ...
# 4   pan-seared salmon with brown butter lime sauce...
# ..                                                ...
# 28  scalloped potato casserole is a gluten free an...
# 29  no-bake cereal bars is a dairy free morn meal....
# 30  you can never have too many dessert recipes, s...
# 31  lemony carrot salad with dill might be just th...
# 32  pineapple squares is a vegetarian hor d'oeuvre...
#
#                                          instructions  \
# 0   for garlic broth: add all ingredients to the s...
# 1    if you're using ground turkey, start out by b...
# 2   wash and rinse pork chops and place into the s...
# 3   layer your bowl with refried beans.add a layer...
# 4    in a frying pan, melt the butter over medium-...
# ..                                                ...
# 28                                                NaN
# 29  directions in a large saucepan, cook and stir ...
# 30  directions in a microwave, melt chocolate chip...
# 31                                                NaN
# 32  crust:preheat oven to 350º.mix together butter...
#
#                                           Ingredients  vegetarian  vegan  \
# 0   extra virgin olive oil; butter; sweet onions; ...        True  False
# 1   bell pepper; canned diced tomatoes; cooked egg...       False  False
# 2   bow tie pasta; parmigiano reggiano; pasta; por...       False  False
# 3   avocado; canned tomatoes; cilantro; green chil...        True  False
# 4   asparagus spears; butter; butter; garlic; lime...       False  False
# ..                                                ...         ...    ...
# 28  celery; chives; egg; fresh tarragon; juice of ...        True  False
# 29  whipping cream; semi sweet chocolate chips; st...       False  False
# 30  bicarbonate of soda; butter; dark chocolate; e...       False  False
# 31  cream; mascarpone cheese; savoiardi; sugar; ma...        True   True
# 32  avocado; corn tortillas; fresh cilantro; garli...        True  False
#
#     glutenFree  dairyFree  veryHealthy  cheap  veryPopular  sustainable  \
# 0         True      False        False  False        False        False
# 1        False      False        False  False        False        False
# 2        False      False        False  False        False        False
# 3         True      False        False  False        False        False
# 4         True      False        False  False        False        False
# ..         ...        ...          ...    ...          ...          ...
# 28        True      False        False  False         True        False
# 29       False       True        False  False         True        False
# 30       False      False        False  False        False        False
# 31        True       True         True  False         True        False
# 32       False      False        False  False        False        False
#
#     healthScore  pricePerServing  readyInMinutes  servings  \
# 0          26.0           510.34              45         6
# 1          13.0           204.73              45         6
# 2          20.0           145.24              35         5
# 3          22.0           106.64              15        12
# 4          35.0           554.27              45         4
# ..          ...              ...             ...       ...
# 28         11.0            66.37              45         4
# 29          2.0            10.25              20       120
# 30          2.0            68.42              70        14
# 31         61.0            66.95              15         4
# 32          0.0            21.08              50        24
#
#                                                 diets
# 0   ['gluten free', 'lacto ovo vegetarian', 'primal']
# 1                                                 NaN
# 2                                                 NaN
# 3             ['gluten free', 'lacto ovo vegetarian']
# 4            ['gluten free', 'primal', 'pescatarian']
# ..                                                ...
# 28            ['gluten free', 'lacto ovo vegetarian']
# 29                                     ['dairy free']
# 30                                                NaN
# 31  ['gluten free', 'dairy free', 'paleolithic', '...
# 32                           ['lacto ovo vegetarian']
#
# [3859 rows x 17 columns]

# %% [markdown]
# ## Export the resulting pd as csv

# %%
df.to_csv(f"data/cleaneddata.csv")
