# %%
import pandas as pd
import numpy as np
from ast import literal_eval
import re

# %%
df = pd.read_csv("./data/recipedata-grouped.csv", index_col=0)

# %% [markdown]
# ## Remove columns that we are not going to use

# %% [markdown]
# We are going to drop columns we are not interested in, and columns with too many missing values.

# %%
df = df.drop(['id', 
              'gaps',
              'lowFodmap', 
              'aggregateLikes', 
              'spoonacularScore',
              'weightWatcherSmartPoints',
              'creditsText', 
              'sourceName',
              'sourceUrl', 
              'image', 
              'imageType',
              'occasions',
              'author', 
              'nutrition', 
              'winePairing',
              'originalId', 
              'spoonacularSourceUrl', 
              'license', 
              'preparationMinutes', 
              'cookingMinutes', 
              'cuisines',
              # 'diets', 
              'dishTypes', 'analyzedInstructions'], axis=1)
# df.head()

# %% [markdown]
# ## Drop data points with missing data (if needed)

# %%
# check how many missing values we have for each column
count_missing = df.replace('[]', np.nan)
for column in count_missing.columns:
    col = count_missing[column]
    n_empty = sum(col.isna()==True)
    print(column, n_empty)
# Out:
# vegetarian 0
# vegan 0
# glutenFree 0
# dairyFree 0
# veryHealthy 0
# cheap 0
# veryPopular 0
# sustainable 0
# healthScore 0
# pricePerServing 0
# extendedIngredients 0
# title 0
# readyInMinutes 0
# servings 0
# summary 5
# diets 914
# instructions 201

# %% [markdown]
# We only have missing values in the "summary", "diets" and "instructions" columns. I am going to keep all the data points, but you can drop some of them if you want.

# %%
print("Before dropping rows: ", df.shape)
# df = df.dropna()
print("After dropping rows:", df.shape)
# Out:
# Before dropping rows:  (4305, 17)
# After dropping rows: (4305, 17)

# %%
df.head()
# Out:
#    vegetarian  vegan  glutenFree  dairyFree  veryHealthy  cheap  veryPopular  \
# 0        True  False       False      False        False  False        False
# 1        True  False       False      False        False  False        False
# 2        True  False       False       True        False  False        False
# 3       False  False        True       True        False  False        False
# 4       False  False       False      False        False  False        False
#
#    sustainable  healthScore  pricePerServing  \
# 0        False          3.0            75.55
# 1        False         15.0           147.70
# 2        False          1.0            26.06
# 3        False         17.0           242.23
# 4        False         12.0           417.69
#
#                                  extendedIngredients  \
# 0  [{'id': 20081, 'aisle': 'Baking', 'image': 'fl...
# 1  [{'id': 18064, 'aisle': 'Bakery/Bread', 'image...
# 2  [{'id': 20081, 'aisle': 'Baking', 'image': 'fl...
# 3  [{'id': 9003, 'aisle': 'Produce', 'image': 'ap...
# 4  [{'id': 98853, 'aisle': 'Pasta and Rice;Refrig...
#
#                                                title  readyInMinutes  \
# 0              Orange-Fig Teacake with Caramel Glaze              45
# 1  Poached Eggs On A Bed Of Fried Mushrooms and C...              45
# 2                                Pandan Chiffon Cake              45
# 3           Pork Chop with Honey, Mustard and Apples              45
# 4     Beet Gnocchi With Steak and Brown Butter Sauce              45
#
#    servings                                            summary  \
# 0        10  Orange-Fig Teacake with Caramel Glaze is a <b>...
# 1         2  Poached Eggs On A Bed Of Fried Mushrooms and C...
# 2         9  For <b>26 cents per serving</b>, this recipe <...
# 3         4  Pork Chop with Honey, Mustard and Apples might...
# 4         4  The recipe Beet Gnocchi With Steak and Brown B...
#
#                                                diets  \
# 0                           ['lacto ovo vegetarian']
# 1                           ['lacto ovo vegetarian']
# 2             ['dairy free', 'lacto ovo vegetarian']
# 3  ['gluten free', 'dairy free', 'paleolithic', '...
# 4                                                 []
#
#                                         instructions
# 0  <ol><li>You will need a 9" springform pan, or ...
# 1  <ol><li>In a frying pan heat up oil then add m...
# 2  <ol><li>Preheat the oven to 170C.</li><li>Blen...
# 3  <ol><li>Pre-heat your oven to 200C / 400F.</li...
# 4  Cooking beets\nHeat oven to 400 degrees\nWash ...

# %% [markdown]
# ## Convert the `extendedIngredients` column to a simple list of ingredient names

# %%
evaluated_ingredient = pd.DataFrame(map(literal_eval, df["extendedIngredients"]))
evaluated_diets = pd.DataFrame(map(literal_eval, df["diets"]))

# %%
row, ingredient_col = evaluated_ingredient.shape
diet_row, diet_col = evaluated_diets.shape

assert row==diet_row,'row count should be the same'

all_ingredients = []
all_ingredient_type = []
all_diets = []

for r in range(row):
    ingredient_names = []
    ingredient_types = []
    
    for c in range(ingredient_col):
        ingredient = evaluated_ingredient.iloc[r,c]
        if ingredient: 

            name = ingredient["name"]
            if name: ingredient_names.append(name)
            
            ingredient_type = ingredient["aisle"]
            if ingredient_type: 
                ingredient_type = re.split('; |, |;|,|\/|\n', ingredient_type)
                ingredient_type = " ".join(ingredient_type)
                ingredient_types.append(ingredient_type)
    
    ingredient_names = "; ".join(ingredient_names) if len(ingredient_names) > 0 else np.nan
    all_ingredients.append(ingredient_names)
    
    ingredient_types = " ".join(set(ingredient_types)) if len(ingredient_types) > 0 else np.nan
    all_ingredient_type.append(ingredient_types)
    
    
    diets = []
    for c in range(diet_col):
        diet = evaluated_diets.iloc[r,c]
        if diet:
            diets.append(diet)
    # diets += ["-".join(d.split()) for d in diets]
    diets = "; ".join(diets) if len(diets) > 0 else np.nan
    all_diets.append(diets)

# %%
df["ingredients"] = pd.Series(all_ingredients)
df["ingredient types"] = pd.Series(all_ingredient_type)
df["diets"] = pd.Series(all_diets)

# %% [markdown]
# If you want to keep the `extendIngredients` column, do not run the following cell.

# %%
df = df.drop(["extendedIngredients"], axis=1)

# %%
# rearrange the columns
columns = df.columns.tolist()
columns = ['title',
           'summary',
           'instructions',
           'ingredients',
           'ingredient types', 
           'diets',
           'vegetarian',
           'vegan',
           'glutenFree',
           'dairyFree',
           'veryHealthy',
           'cheap',
           'veryPopular',
           'sustainable',
           'healthScore',
           'pricePerServing',
           'readyInMinutes',
           'servings',]

# %%
df = df[columns]

# %%
df.head()
# Out:
#                                                title  \
# 0              Orange-Fig Teacake with Caramel Glaze
# 1  Poached Eggs On A Bed Of Fried Mushrooms and C...
# 2                                Pandan Chiffon Cake
# 3           Pork Chop with Honey, Mustard and Apples
# 4     Beet Gnocchi With Steak and Brown Butter Sauce
#
#                                              summary  \
# 0  Orange-Fig Teacake with Caramel Glaze is a <b>...
# 1  Poached Eggs On A Bed Of Fried Mushrooms and C...
# 2  For <b>26 cents per serving</b>, this recipe <...
# 3  Pork Chop with Honey, Mustard and Apples might...
# 4  The recipe Beet Gnocchi With Steak and Brown B...
#
#                                         instructions  \
# 0  <ol><li>You will need a 9" springform pan, or ...
# 1  <ol><li>In a frying pan heat up oil then add m...
# 2  <ol><li>Preheat the oven to 170C.</li><li>Blen...
# 3  <ol><li>Pre-heat your oven to 200C / 400F.</li...
# 4  Cooking beets\nHeat oven to 400 degrees\nWash ...
#
#                                          ingredients  \
# 0  AP flour; baking powder; cardamom; eggs; fresh...
# 1  bread; butter; eggs; eggs; mushrooms; oil; sal...
# 2  all purpose flour; bay leaves; coconut milk; c...
# 3  apples; dijon mustard; garlic cloves; honey; j...
# 4  gnocchi; beets; olive oil; s&p; goat cheese; r...
#
#                                     ingredient types  \
# 0  Beverages Milk Eggs Other Dairy Spices and Sea...
# 1  Beverages Milk Eggs Other Dairy Spices and Sea...
# 2  Ethnic Foods Produce Spices and Seasonings Bev...
# 3  Meat Spices and Seasonings Condiments Oil Vine...
# 4  Produce Spices and Seasonings Meat Spices and ...
#
#                                           diets  vegetarian  vegan  \
# 0                          lacto ovo vegetarian        True  False
# 1                          lacto ovo vegetarian        True  False
# 2              dairy free; lacto ovo vegetarian        True  False
# 3  gluten free; dairy free; paleolithic; primal       False  False
# 4                                           NaN       False  False
#
#    glutenFree  dairyFree  veryHealthy  cheap  veryPopular  sustainable  \
# 0       False      False        False  False        False        False
# 1       False      False        False  False        False        False
# 2       False       True        False  False        False        False
# 3        True       True        False  False        False        False
# 4       False      False        False  False        False        False
#
#    healthScore  pricePerServing  readyInMinutes  servings
# 0          3.0            75.55              45        10
# 1         15.0           147.70              45         2
# 2          1.0            26.06              45         9
# 3         17.0           242.23              45         4
# 4         12.0           417.69              45         4

# %% [markdown]
# ## Remove the html tags, urls and line breaks from the text data

# %% [markdown]
# We will use the following four columns as text data:
# 1. title
# 2. summary
# 3. instructions
# 4. ingredients

# %%
for r in range(row):
    for c in range(4): # only the 4 first columns are text data that we are going to use
        text = df.iloc[r, c]
        if text is not np.nan and text is not None:
            # remove line breaks and html tags
            text = re.sub(r"<[^>]*>|[\n\r]+", " ", text).lower()
            # remove urls 
            text = re.sub(r"https?:\/\/(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)", " ", text)
            # remove extra spaces
            text = re.sub(r"\s\s+", " ", text)
            # remove special symbols
            text = re.sub(r'[\!"#$%&\*+,-./:<=>?@^_`()|~=]|\n', " ", text)
            if df.columns[c] not in ["ingredients", "diets"]:
                text = re.sub(r';', " ", text)
            df.iloc[r, c] = text

# %%
df.head()
# Out:
#                                                title  \
# 0              orange fig teacake with caramel glaze
# 1  poached eggs on a bed of fried mushrooms and c...
# 2                                pandan chiffon cake
# 3           pork chop with honey  mustard and apples
# 4     beet gnocchi with steak and brown butter sauce
#
#                                              summary  \
# 0  orange fig teacake with caramel glaze is a veg...
# 1  poached eggs on a bed of fried mushrooms and c...
# 2  for 26 cents per serving   this recipe covers ...
# 3  pork chop with honey  mustard and apples might...
# 4  the recipe beet gnocchi with steak and brown b...
#
#                                         instructions  \
# 0   you will need a 9  springform pan  or a cake ...
# 1   in a frying pan heat up oil then add mushroom...
# 2   preheat the oven to 170c  blend the pandan le...
# 3   pre heat your oven to 200c   400f  line a roa...
# 4  cooking beets heat oven to 400 degrees wash be...
#
#                                          ingredients  \
# 0  ap flour; baking powder; cardamom; eggs; fresh...
# 1  bread; butter; eggs; eggs; mushrooms; oil; sal...
# 2  all purpose flour; bay leaves; coconut milk; c...
# 3  apples; dijon mustard; garlic cloves; honey; j...
# 4  gnocchi; beets; olive oil; s p; goat cheese; r...
#
#                                     ingredient types  \
# 0  Beverages Milk Eggs Other Dairy Spices and Sea...
# 1  Beverages Milk Eggs Other Dairy Spices and Sea...
# 2  Ethnic Foods Produce Spices and Seasonings Bev...
# 3  Meat Spices and Seasonings Condiments Oil Vine...
# 4  Produce Spices and Seasonings Meat Spices and ...
#
#                                           diets  vegetarian  vegan  \
# 0                          lacto ovo vegetarian        True  False
# 1                          lacto ovo vegetarian        True  False
# 2              dairy free; lacto ovo vegetarian        True  False
# 3  gluten free; dairy free; paleolithic; primal       False  False
# 4                                           NaN       False  False
#
#    glutenFree  dairyFree  veryHealthy  cheap  veryPopular  sustainable  \
# 0       False      False        False  False        False        False
# 1       False      False        False  False        False        False
# 2       False       True        False  False        False        False
# 3        True       True        False  False        False        False
# 4       False      False        False  False        False        False
#
#    healthScore  pricePerServing  readyInMinutes  servings
# 0          3.0            75.55              45        10
# 1         15.0           147.70              45         2
# 2          1.0            26.06              45         9
# 3         17.0           242.23              45         4
# 4         12.0           417.69              45         4

# %% [markdown]
# ## Export the resulting pd as csv

# %%
df.to_csv(f"data/cleaneddata.csv")
